# %% [markdown]
# The drift difussion model (DDM) is a type of sequential sampling model (SSM) which, until now, has been uniquely applied in impulsive / non-deliberated two-choice decisions. These SSM models, and thus the DDM, assume that decisions are made by accumulating information until a threshold is reached. In order to model this accumulation of knowledge, DDM uses a random walk in two dimensions, starting at point z and finishing when it reaches a decision threshold (a or 0).
#
# The starting point z can be understood as an initial bias, which can be due to previous experiences or intuitive notions. On the other hand, the boundaries represent the minimum accumulated knowledge needed to make a decision, so harder decisions will have wider boundaries than simple choices.
#
# The speed by which the information is accumulated is defined as $v$ (drift rate) and it is a constant value throughout the experiment. In past papers, the drift rate $v$ has been defined positive when the accumulation of information led to the right decision (and negative in the opposite case) but, as decisions in cooperation-defection experiments are not right or wrong, $v$ will be defined as positive when the accumulation of knowledge leads to a cooperative choice (and negative on the contrary).
#
# Apart from the drift rate, there is a source of stochastic noise in the decision process. Using the same parameters v and z, this noise will lead to different final decisions and different final times. Thevariability in decision times will produce the characteristic distribution of RT (reaction time) and the two possible final decisions will bring errors and the corresponding error RT distribution.
#
# One last parameter $t_0$?
#
# The equation which represents the probability distribution:
# $$P(t| v,a,z)=\frac{\pi}{a^2}\exp{(-vza-\frac{v^2 t}{2})} × \sum_{k=1}^\infty k \exp{(-\frac{k^2\pi ^2 t}{2a^2})}\sin{(k\pi z)}$$

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5112760/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4928591/
# http://star.psy.ohio-state.edu/wp/?page_id=169

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
# %matplotlib inline
import hddm
print(hddm.__version__)
# Out:
# 0.6.0

# %%
def parse_files(files_to_parse):
    o=open("output_data.dat","w")
    for index,i in enumerate(files_to_parse):
        if index==0:
            for line in open("Esther/history_"+i+".dat"):
                o.write(line.replace(" ",",").replace("usuario",i+"_usuario")) 
        else:
            f=open("Esther/history_"+i+".dat")
            f.readline()
            for line in f:
                o.write(line.replace(" ",",").replace("usuario",i+"_usuario") ) 
    o.close()
    return 

files_to_parse=["s3m7","s4m8","s5m20","s6m22","s7m22","s8n3","s9n3","s10n5","s11n9","s13n12","s12n11"]
parse_files(files_to_parse)

# %%
data = hddm.load_csv('output_data.dat')
data.head()
# Out:
#    round          player action_player            opponent action_opponent  \
# 0      1   s3m7_usuario9             D  ['s3m7_usuario18']               C
# 1      1  s3m7_usuario18             C   ['s3m7_usuario9']               D
# 2      1   s3m7_usuario7             C  ['s3m7_usuario10']               C
# 3      1  s3m7_usuario10             C   ['s3m7_usuario7']               C
# 4      1  s3m7_usuario13             C   ['s3m7_usuario5']               C
#
#    payoff     time_php  time_js who_played
# 0       4  4480.199814     4452       user
# 1       0  9472.300053     9443       user
# 2       3  2238.199949     2213       user
# 3       3  8133.699894     8101       user
# 4       3  5098.500013     5043       user

# %%
set(data["player"])
# Out:
# {'s10n5_usuario1',
#  's10n5_usuario2',
#  's10n5_usuario3',
#  's10n5_usuario4',
#  's10n5_usuario5',
#  's10n5_usuario6',
#  's10n5_usuario7',
#  's10n5_usuario8',
#  's11n9_usuario1',
#  's11n9_usuario10',
#  's11n9_usuario2',
#  's11n9_usuario3',
#  's11n9_usuario4',
#  's11n9_usuario5',
#  's11n9_usuario6',
#  's11n9_usuario7',
#  's11n9_usuario8',
#  's11n9_usuario9',
#  's12n11_usuario1',
#  's12n11_usuario10',
#  's12n11_usuario11',
#  's12n11_usuario12',
#  's12n11_usuario13',
#  's12n11_usuario14',
#  's12n11_usuario15',
#  's12n11_usuario16',
#  's12n11_usuario17',
#  's12n11_usuario18',
#  's12n11_usuario2',
#  's12n11_usuario3',
#  's12n11_usuario4',
#  's12n11_usuario5',
#  's12n11_usuario6',
#  's12n11_usuario7',
#  's12n11_usuario8',
#  's12n11_usuario9',
#  's13n12_usuario1',
#  's13n12_usuario10',
#  's13n12_usuario11',
#  's13n12_usuario12',
#  's13n12_usuario13',
#  's13n12_usuario14',
#  's13n12_usuario15',
#  's13n12_usuario16',
#  's13n12_usuario2',
#  's13n12_usuario3',
#  's13n12_usuario4',
#  's13n12_usuario5',
#  's13n12_usuario6',
#  's13n12_usuario7',
#  's13n12_usuario8',
#  's13n12_usuario9',
#  's3m7_usuario1',
#  's3m7_usuario10',
#  's3m7_usuario11',
#  's3m7_usuario12',
#  's3m7_usuario13',
#  's3m7_usuario14',
#  's3m7_usuario15',
#  's3m7_usuario16',
#  's3m7_usuario17',
#  's3m7_usuario18',
#  's3m7_usuario2',
#  's3m7_usuario3',
#  's3m7_usuario4',
#  's3m7_usuario5',
#  's3m7_usuario6',
#  's3m7_usuario7',
#  's3m7_usuario8',
#  's3m7_usuario9',
#  's4m8_usuario1',
#  's4m8_usuario10',
#  's4m8_usuario11',
#  's4m8_usuario12',
#  's4m8_usuario13',
#  's4m8_usuario14',
#  's4m8_usuario2',
#  's4m8_usuario3',
#  's4m8_usuario4',
#  's4m8_usuario5',
#  's4m8_usuario6',
#  's4m8_usuario7',
#  's4m8_usuario8',
#  's4m8_usuario9',
#  's5m20_usuario1',
#  's5m20_usuario10',
#  's5m20_usuario11',
#  's5m20_usuario12',
#  's5m20_usuario13',
#  's5m20_usuario14',
#  's5m20_usuario15',
#  's5m20_usuario16',
#  's5m20_usuario17',
#  's5m20_usuario18',
#  's5m20_usuario2',
#  's5m20_usuario3',
#  's5m20_usuario4',
#  's5m20_usuario5',
#  's5m20_usuario6',
#  's5m20_usuario7',
#  's5m20_usuario8',
#  's5m20_usuario9',
#  's6m22_usuario1',
#  's6m22_usuario10',
#  's6m22_usuario11',
#  's6m22_usuario12',
#  's6m22_usuario13',
#  's6m22_usuario14',
#  's6m22_usuario15',
#  's6m22_usuario16',
#  's6m22_usuario2',
#  's6m22_usuario3',
#  's6m22_usuario4',
#  's6m22_usuario5',
#  's6m22_usuario6',
#  's6m22_usuario7',
#  's6m22_usuario8',
#  's6m22_usuario9',
#  's7m22_usuario1',
#  's7m22_usuario10',
#  's7m22_usuario11',
#  's7m22_usuario12',
#  's7m22_usuario13',
#  's7m22_usuario14',
#  's7m22_usuario15',
#  's7m22_usuario16',
#  's7m22_usuario17',
#  's7m22_usuario18',
#  's7m22_usuario2',
#  's7m22_usuario3',
#  's7m22_usuario4',
#  's7m22_usuario5',
#  's7m22_usuario6',
#  's7m22_usuario7',
#  's7m22_usuario8',
#  's7m22_usuario9',
#  's8n3_usuario1',
#  's8n3_usuario10',
#  's8n3_usuario11',
#  's8n3_usuario12',
#  's8n3_usuario13',
#  's8n3_usuario14',
#  's8n3_usuario15',
#  's8n3_usuario16',
#  's8n3_usuario17',
#  's8n3_usuario18',
#  's8n3_usuario2',
#  's8n3_usuario3',
#  's8n3_usuario4',
#  's8n3_usuario5',
#  's8n3_usuario6',
#  's8n3_usuario7',
#  's8n3_usuario8',
#  's8n3_usuario9',
#  's9n3_usuario1',
#  's9n3_usuario10',
#  's9n3_usuario11',
#  's9n3_usuario12',
#  's9n3_usuario13',
#  's9n3_usuario14',
#  's9n3_usuario15',
#  's9n3_usuario16',
#  's9n3_usuario17',
#  's9n3_usuario18',
#  's9n3_usuario2',
#  's9n3_usuario3',
#  's9n3_usuario4',
#  's9n3_usuario5',
#  's9n3_usuario6',
#  's9n3_usuario7',
#  's9n3_usuario8',
#  's9n3_usuario9'}

# %%
#only user (not autom) and delete "who played"
data=data[data["who_played"]=="user"]
del data["who_played"]

#rename for rt and response columns
data.rename(columns={'time_js':'rt', "action_player":"response"}, inplace=True) 

#make rt floats
data['rt'] = data.rt.astype(int)

#coop is 1, defl is 0
data.loc[data['response'] == "C", "response"] = 1.0
data.loc[data['response'] == "D", "response"] = 0.0
data.loc[data['action_opponent'] == "C", "action_opponent"] = 1.0
data.loc[data['action_opponent'] == "D", "action_opponent"] = 0.0

#add strategy
data["strategy"]=[str(data["response"][i])+str(data["action_opponent"][i]) for i in range(len(data))]

#rt in seconds
data["rt"]=data["rt"]/1000

#rt which are defect become neg
data = hddm.utils.flip_errors(data)

data2=data.copy()
data2.rename(columns={"player":"subj_idx"},inplace=True)

data=data[(data["rt"]<=20) & (data["rt"]>=-20)]
data.head()
# Out:
#    round          player  response            opponent  action_opponent  \
# 0      1   s3m7_usuario9         0  ['s3m7_usuario18']                1
# 1      1  s3m7_usuario18         1   ['s3m7_usuario9']                0
# 2      1   s3m7_usuario7         1  ['s3m7_usuario10']                1
# 3      1  s3m7_usuario10         1   ['s3m7_usuario7']                1
# 4      1  s3m7_usuario13         1   ['s3m7_usuario5']                1
#
#    payoff     time_php     rt strategy
# 0       4  4480.199814 -4.452       01
# 1       0  9472.300053  9.443       10
# 2       3  2238.199949  2.213       11
# 3       3  8133.699894  8.101       11
# 4       3  5098.500013  5.043       11

# %%
data2.head() #data2 will be used to plot by player
# Out:
#    round        subj_idx  response            opponent  action_opponent  \
# 0      1   s3m7_usuario9         0  ['s3m7_usuario18']                1
# 1      1  s3m7_usuario18         1   ['s3m7_usuario9']                0
# 2      1   s3m7_usuario7         1  ['s3m7_usuario10']                1
# 3      1  s3m7_usuario10         1   ['s3m7_usuario7']                1
# 4      1  s3m7_usuario13         1   ['s3m7_usuario5']                1
#
#    payoff     time_php     rt strategy
# 0       4  4480.199814 -4.452       01
# 1       0  9472.300053  9.443       10
# 2       3  2238.199949  2.213       11
# 3       3  8133.699894  8.101       11
# 4       3  5098.500013  5.043       11

# %%
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions')
data.rt.hist(bins="auto",  ax=ax, density=True, histtype="stepfilled")
plt.legend(["coop: +; defect: -"])
#plt.savefig('jelena_rt.png')

# %%
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
data.rt.hist(log=True,bins="auto",  ax=ax, density=True, histtype="stepfilled")
plt.legend(["coop: +; defect: -"])
plt.savefig('jelena_rt_logscale.png')

# %%
#basic model
m = hddm.HDDM(data)
# find a good starting point which helps with the convergence.
m.find_starting_values()
m.sample(2000, burn=20)
# Out:
# -40668.6046083
# -40653.3134421
#  [-----------------100%-----------------] 2000 of 2000 complete in 111.5 sec

# %%
#get statistics from a t and v
stats = m.gen_stats()
#stats[stats.index.isin(['a', "t", 'v'])]
stats
# Out:
#         mean         std       2.5q        25q        50q        75q  \
# a    2.94071   0.0104017    2.92054    2.93348    2.94086    2.94783
# v -0.0697973  0.00529551 -0.0803287 -0.0733134 -0.0696774 -0.0662632
# t  0.0835386  0.00451509  0.0747134  0.0805062   0.083728  0.0866953
#
#        97.5q       mc err
# a    2.96177  0.000320435
# v -0.0595625   0.00012219
# t  0.0919269  0.000142771

# %%
#check convergence
m.plot_posteriors()
#no drifts or large jumps in the trace (non stationary). The autocorrelation is also very low.
# Out:
# Plotting a
# Plotting v
# Plotting t

# %%
#basic model by players
m2 = hddm.HDDM(data2, p_outlier=.05)
# find a good starting point which helps with the convergence.
m2.find_starting_values()
m2.sample(2000, burn=20)
#by player
#m2.plot_posterior_predictive(figsize=(24, 60))
#m2.gen_starts()
# Out:
# /opt/anaconda3/envs/DecTimesEnv/lib/python2.7/site-packages/scipy/optimize/optimize.py:1934: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
#  [-----------------100%-----------------] 2000 of 2000 complete in 426.4 sec

# %%
m2.plot_posterior_predictive(figsize=(24, 60))
# Out:
# /opt/anaconda3/envs/DecTimesEnv/lib/python2.7/site-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-7f02f1933d9b> in <module>()
# ----> 1 m2.plot_posterior_predictive(figsize=(24, 60))
#
# /opt/anaconda3/envs/DecTimesEnv/lib/python2.7/site-packages/hddm/models/base.pyc in plot_posterior_predictive(self, *args, **kwargs)
#     726         if 'value_range' not in kwargs:
#     727             kwargs['value_range'] = np.linspace(-5, 5, 100)
# --> 728         kabuki.analyze.plot_posterior_predictive(self, *args, **kwargs)
#     729
#     730     def plot_posterior_quantiles(self, *args, **kwargs):
#
# /opt/anaconda3/envs/DecTimesEnv/lib/python2.7/site-packages/kabuki/analyze.pyc in plot_posterior_predictive(model, plot_func, required_method, columns, save, path, figsize, format, num_subjs, **kwargs)
#     553                 continue # skip nodes that do not define the required_method
#     554
# --> 555             ax = fig.add_subplot(np.ceil(len(nodes)/columns), columns, subj_i+1)
#     556             if 'subj_idx' in bottom_node:
#     557                 ax.set_title(str(bottom_node['subj_idx']))
#
# /opt/anaconda3/envs/DecTimesEnv/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1255                     self._axstack.remove(ax)
#    1256
# -> 1257             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1258         self._axstack.add(key, a)
#    1259         self.sca(a)
#
# /opt/anaconda3/envs/DecTimesEnv/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      65                     raise ValueError(
#      66                         ("num must be 1 <= num <= {maxn}, not {num}"
# ---> 67                         ).format(maxn=rows*cols, num=num))
#      68                 self._subplotspec = GridSpec(
#      69                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <=
#hddm.analyze.plot_posterior_nodes([v_WW, v_LL, v_WL, v_LW])
#plt.xlabel('drift-rate')
#plt.ylabel('Posterior probability')
#plt.title('Posterior of drift-rate group means')
#plt.savefig('hddm_demo_fig_06.pdf')
# Out:
# -30353.2724817
# -30353.2724817
#  [-----------------100%-----------------] 10000 of 10000 complete in 532.9 sec

# %%
v_WW, v_LL, v_WL,v_LW = m_stim.nodes_db.node[['v(00)', 'v(01)', 'v(10)','v(11)']]
hddm.analyze.plot_posterior_nodes([v_WW, v_LL, v_WL, v_LW])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.title('Posterior of drift-rate group means')
# Out:
# Text(0.5,1,'Posterior of drift-rate group means')

# %%
#comparing distributions: dealing with outliers 
#comaprison with outlayers to see which model fits better
m_no_outlier = hddm.HDDM(data)
m_no_outlier.sample(2000, burn=50)
m_no_outlier.plot_posterior_predictive()
plt.title('Posterior predictive ')
plt.xlabel('RT')
plt.ylabel('Probability density')
#plt.savefig('hddm_demo_fig_10.pdf')

m_outlier = hddm.HDDM(data, p_outlier=.05)
m_outlier.sample(2000, burn=20)
m_outlier.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
stats3=m_outlier.gen_stats()
print(stats3)
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 2000 of 2000 complete in 504.6 sec
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
#  [-----------------100%-----------------] 2000 of 2000 complete in 465.7 sec       mean         std      2.5q        25q        50q        75q      97.5q  \
# a   2.39896   0.0108826   2.37768    2.39179     2.3989    2.40628    2.42156
# v -0.086966  0.00709016 -0.101044 -0.0917754 -0.0868743 -0.0822121 -0.0729009
# t  0.218244  0.00361806  0.211134    0.21581   0.218308   0.220655   0.225329
#
#         mc err
# a  0.000350633
# v  0.000151909
# t  0.000123473

# %%
#by player

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, xlabel='RT', ylabel='count', title='RT distributions')
for i, subj_data in data.groupby("player"):
    subj_data.rt.hist(log=True,bins=200,  ax=ax,histtype="step")
print(len(data.groupby("player")))
#plt.savefig('hddm_demo_fig_00.pdf')
# Out:
# 172

# %%
#if we want analisis by player change player by subj_idx

m_outlier = hddm.HDDM(data, p_outlier=.05)
m_outlier.sample(2000, burn=20)
m_outlier.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig('jelena_rt_aprox.pdf')
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 2000 of 2000 complete in 479.1 sec
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
#by strategy
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm', title='RT distributions')
for i, subj_data in data.groupby("strategy"):
    subj_data.rt.hist(bins=200,  ax=ax, density=True)
fig.legend(["00","01","10","11"])
#plt.savefig('hddm_demo_fig_00.pdf')
#if player cooperates, oponent choice does not matter for decision time. ohter player choice only matters when we defect

# %%
model = hddm.HDDM(data)

# Create model and start MCMC sampling
model.sample(200, burn=20)

# Print fitted parameters and other model statistics
model.print_stats()

# Plot posterior distributions and theoretical RT distributions
model.plot_posteriors()
model.plot_posterior_predictive()

# %%
#posterior prediction?

# %% [markdown]
# ## Dec Times Elias

# %%
dat = hddm.load_csv('crd_dataset_time_ns.csv')
del dat["time_elapsed_action"], dat["time_elapsed_pred"]
dat.rename(columns={"etimeactionnr":"rt"},inplace=True)
#0 and 4 extreme become 1, 2 becomes 0
dat["response"]=[1 if( dat["actions"][i]==0 or dat["actions"][i]==4) else 0 for i in range(len(dat))]
#rt which are defect become neg
dat = hddm.utils.flip_errors(dat)
dat["rt"]=dat["rt"]/10e9
two=dat[dat["actions"]==2]
zero=dat[dat["actions"]==0]
four=dat[dat["actions"]==4]
dat.head()
# Out:
#    index  actions  age            degree  group  knows_game  knows_gt  \
# 0      0        0   26  Computer Science     21       False       0.0
# 1      1        0   26  Computer Science     21       False       0.0
# 2      2        4   26  Computer Science     21       False       0.0
# 3      3        2   26  Computer Science     21       False       0.0
# 4      4        4   26  Computer Science     21       False       0.0
#
#   level_studies  player  predictions   ...                   time_end_action  \
# 0        master      60         10.0   ...     2017-11-22 07:36:25.118000000
# 1        master      60         10.0   ...     2017-11-22 07:38:10.285000000
# 2        master      60         14.0   ...     2017-11-22 07:34:38.132000000
# 3        master      60         12.0   ...     2017-11-22 07:37:12.092000000
# 4        master      60         16.0   ...     2017-11-22 07:33:27.827000000
#
#                    time_end_pred              time_start_action  \
# 0  2017-11-22 07:36:36.341000000  2017-11-22 07:36:08.645000000
# 1  2017-11-22 07:38:27.301000000  2017-11-22 07:37:44.650000000
# 2  2017-11-22 07:34:59.039000000  2017-11-22 07:34:15.067000000
# 3  2017-11-22 07:37:44.023000000  2017-11-22 07:36:47.005000000
# 4  2017-11-22 07:33:54.327000000  2017-11-22 07:32:59.816000000
#
#                  time_start_pred treatment  gap_threshold round_donations  \
# 0  2017-11-22 07:36:25.683000000         1             74              10
# 1  2017-11-22 07:38:20.974000000         1             56               6
# 2  2017-11-22 07:34:48.792000000         1             92              14
# 3  2017-11-22 07:37:22.734000000         1             62              12
# 4  2017-11-22 07:33:28.451000000         1            106              14
#
#        rt  etimeprednr response
# 0  1.6473  10658000000        1
# 1  2.5635   6327000000        1
# 2  2.3065  10247000000        1
# 3 -2.5087  21289000000        0
# 4  2.8011  25876000000        1
#
# [5 rows x 26 columns]

# %%
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions')
data.rt.hist(bins="auto",  ax=ax, density=True, histtype="stepfilled")
plt.legend(["coop: +; defect: -"])
plt.savefig('elias_rt.png')

# %%
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
dat.rt.hist(log=True,bins=200,  ax=ax, density=True, histtype="stepfilled")
plt.legend(["0 or 4: +; 2: -"])
plt.savefig('elias_rt_logscale.png')

# %%
m_outlier = hddm.HDDM(dat, p_outlier=.05)
m_outlier.sample(2000, burn=20)
m_outlier.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig("elias_rt_aprox.pdf")
statse=m_outlier.gen_stats()
print(statse)
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 2000 of 2000 complete in 40.5 sec        mean        std        2.5q        25q        50q        75q  \
# a    2.75388  0.0330449     2.68699    2.73169    2.75464    2.77601
# v -0.0463907  0.0191021  -0.0839269 -0.0594235 -0.0463881 -0.0333423
# t  0.0183986  0.0072949  0.00630057  0.0129188  0.0177397  0.0231204
#
#         97.5q       mc err
# a      2.8184  0.000793355
# v -0.00945597  0.000482066
# t   0.0346588  0.000188542
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm', title='RT distributions')
for i, subj_data in dat.groupby("actions"):
    subj_data.rt.hist(bins=200,  ax=ax, density=True)
fig.legend(["0","2","4"])

# %%
dat1=dat[dat["rounds"]==1]
dat2=dat[(dat["rounds"]==10)  & (dat["treatment"]==1)]
print(dat2)
# Out:
#      index  actions  age            degree  group  knows_game  knows_gt  \
# 8        8        0   26  Computer Science     21       False       0.0
# 12      12        0   26           Biology     21       False       1.0
# 25      25        2   20        Psychology     21       False       0.0
# 31      31        2   23  Computer Science     21       False       1.0
# 47      47        4   27       Engineering     21       False       0.0
# 58      58        0   24       Engineering     21       False       0.0
# 62      62        2   23  Computer Science     22        True       1.0
# 74      74        4   39           Physics     22        True       0.0
# 87      87        4   23           Economy     22       False       0.0
# 93      93        2   22  Computer Science     22       False       0.0
# 109    109        2   25           Economy     22        True       0.0
# 117    117        0   24             Other     22       False       0.0
# 125    125        4   29             Other     30       False       0.0
# 134    134        4   26           Physics     30        True       1.0
# 146    146        0   25  Computer Science     30       False       1.0
# 155    155        2   20           Economy     30       False       1.0
# 168    168        4   25  Computer Science     30       False       1.0
# 173    173        4   26           Economy     30       False       1.0
# 186    186        4   29             Other     31       False       0.0
# 194    194        0   28       Engineering     31       False       0.0
# 200    200        2   27   Social Sciences     31       False       0.0
# 212    212        2   27  Computer Science     31       False       1.0
# 223    223        2   28       Mathematics     31        True       1.0
# 231    231        2   20        Psychology     31       False       0.0
# 246    246        2   24           Biology     40       False       0.0
# 259    259        2   23  Computer Science     40        True       1.0
# 262    262        2   27  Computer Science     40        True       1.0
# 275    275        4   30       Mathematics     40       False       NaN
# 283    283        2   19             Other     40       False       0.0
# 292    292        0   21             Other     40        True       0.0
# ..     ...      ...  ...               ...    ...         ...       ...
# 426    426        2   26             Other     51       False       0.0
# 439    439        2   31  Computer Science     51       False       1.0
# 447    447        2   20             Other     51        True       1.0
# 453    453        2   18   Social Sciences     51       False       1.0
# 469    469        2   31           Economy     51        True       1.0
# 470    470        2   18   Social Sciences     51       False       0.0
# 486    486        2   25        Psychology     60       False       0.0
# 498    498        4   25       Engineering     60       False       0.0
# 503    503        2   21             Other     60       False       1.0
# 510    510        4   24  Computer Science     60       False       1.0
# 528    528        2   25  Computer Science     60       False       1.0
# 531    531        4   24  Computer Science     60       False       1.0
# 540    540        4   26   Social Sciences     61       False       0.0
# 559    559        0   28  Computer Science     61       False       1.0
# 565    565        0   30       Engineering     61       False       1.0
# 574    574        0   21  Computer Science     61       False       0.0
# 580    580        0   20       Engineering     61       False       0.0
# 598    598        4   29   Social Sciences     61       False       0.0
# 607    607        4   30           Economy     70       False       1.0
# 612    612        0   23  Computer Science     70       False       1.0
# 624    624        2   22             Other     70       False       0.0
# 634    634        2   23        Psychology     70        True       0.0
# 640    640        4   24  Computer Science     70        True       1.0
# 659    659        4   28           Economy     70       False       1.0
# 666    666        4   22             Other     71       False       1.0
# 678    678        4   24         Languages     71        True       1.0
# 682    682        0   33  Computer Science     71       False       0.0
# 699    699        4   25  Computer Science     71        True       1.0
# 701    701        0   25             Other     71       False       0.0
# 715    715        0   24         Languages     71       False       0.0
#
#     level_studies  player  predictions   ...     \
# 8          master      60         14.0   ...
# 12         master      61         10.0   ...
# 25       bachelor      63        120.0   ...
# 31       bachelor      69        122.0   ...
# 47         master      71        120.0   ...
# 58         master      74        125.0   ...
# 62         master      58        120.0   ...
# 74   postdoctoral      64        120.0   ...
# 87    high school      66        120.0   ...
# 93         master      67        122.0   ...
# 109           PhD      72        112.0   ...
# 117      bachelor      75        122.0   ...
# 125        master      77        121.0   ...
# 134        master      78        118.0   ...
# 146        master      85        118.0   ...
# 155      bachelor      89        120.0   ...
# 168           PhD      90        120.0   ...
# 173        master      92        120.0   ...
# 186           PhD      79        120.0   ...
# 194        master      82        120.0   ...
# 200        master      84        124.0   ...
# 212        master      87        122.0   ...
# 223        master      88        120.0   ...
# 231      bachelor      91        124.0   ...
# 246        master      99        120.0   ...
# 259        master     105        126.0   ...
# 262        master     107        122.0   ...
# 275        master     108        120.0   ...
# 283      bachelor     109        120.0   ...
# 292      bachelor     111        120.0   ...
# ..            ...     ...          ...   ...
# 426        master     112        120.0   ...
# 439        master     117        120.0   ...
# 447      bachelor     118        120.0   ...
# 453      bachelor     119        120.0   ...
# 469           PhD     121        120.0   ...
# 470      bachelor     125        120.0   ...
# 486        master     131        120.0   ...
# 498        master     132        120.0   ...
# 503        master     135        118.0   ...
# 510        master     138        122.0   ...
# 528        master     140        130.0   ...
# 531        master     142        122.0   ...
# 540        master     134        123.0   ...
# 559           PhD     136        108.0   ...
# 565  postdoctoral     139         92.0   ...
# 574      bachelor     144        120.0   ...
# 580      bachelor     145        120.0   ...
# 598      bachelor     146        118.0   ...
# 607           PhD     149        122.0   ...
# 612        master     150        120.0   ...
# 624        master     156        118.0   ...
# 634        master     158        120.0   ...
# 640           PhD     162        116.0   ...
# 659           PhD     163        122.0   ...
# 666        master     152         18.0   ...
# 678        master     153        122.0   ...
# 682  postdoctoral     154        124.0   ...
# 699        master     157        120.0   ...
# 701      bachelor     160         86.0   ...
# 715      bachelor     164        120.0   ...
#
#                    time_end_action                  time_end_pred  \
# 8    2017-11-22 07:43:19.805000000  2017-11-22 07:43:32.592000000
# 12   2017-11-21 15:39:34.034000000  2017-11-21 15:40:12.225000000
# 25   2017-11-21 15:54:21.566000000  2017-11-21 15:55:28.330000000
# 31   2017-11-21 15:38:59.998000000  2017-11-21 15:40:09.202000000
# 47   2017-11-22 07:35:53.248000000  2017-11-22 07:36:54.279000000
# 58   2017-11-22 07:53:13.600000000  2017-11-22 07:54:26.965000000
# 62   2017-11-22 07:30:48.859000000  2017-11-22 07:31:03.440000000
# 47              10               8  1.6234  10024000000        1
# 58              10               8  0.5661  12368000000        1
# 62               2              14 -3.3839  13970000000        0
# 74               2              14  3.1810  23720000000        1
# 87              -4              14  5.0648   8424000000        1
# 93              -6              14 -8.5841   7992000000        0
# 109              0              14 -3.4541   6160000000        0
# 117              8              14  1.5693   4731000000        1
# 125             -4              18  2.8179  38804000000        1
# 134             -4              18  3.8945   5482000000        1
# 146             -4              18  5.1035  12104000000        1
# 155             -4              18 -0.2977   8310000000        0
# 168             -4              18  0.9871  11408000000        1
# 173             -4              18  3.2528  15267000000        1
# 186             -6              12  3.3163   8215000000        1
# 194             -6              12  2.5824   7079000000        1
# 200             -6              12 -1.7564   9585000000        0
# 212             -6              12 -1.6075  19910000000        0
# 223             -6              12 -2.9556   8271000000        0
# 231             -6              12 -2.3010  13840000000        0
# 246             -6              12 -6.1712   7896000000        0
# 259             -6              12 -1.5646   8794000000        0
# 262             -6              12 -1.1229   9939000000        0
# 275             -6              12  1.2480   9919000000        1
# 283             -6              12 -1.2151   6328000000        0
# 292             -6              12  1.2247   9678000000        1
# ..             ...             ...     ...          ...      ...
# 426              0              12 -0.5277   9084000000        0
# 439              0              12 -0.2512   5054000000        0
# 447              0              12 -0.4243   8033000000        0
# 453              0              12 -0.4876   6007000000        0
# 469              0              12 -0.2898   5402000000        0
# 470              0              12 -0.1949  18356000000        0
# 486             -2              18 -3.0092   5805000000        0
# 498             -2              18  3.1931  11553000000        1
# 503             -2              18 -1.2820  12165000000        0
# 510             -2              18  2.4808  12875000000        1
# 528             -2              18 -1.4050   6812000000        0
# 531             -2              18  6.6188  14121000000        1
# 540              4               8  1.2326   7434000000        1
# 559              4               8  5.6529  17177000000        1
# 565              4               8  1.2133  12751000000        1
# 574              4               8  2.1094  12159000000        1
# 580              4               8  0.7691   5446000000        1
# 598              4               8  0.4466  24387000000        1
# 607              0              16  2.2977  12156000000        1
# 612              0              16  3.6918  12895000000        1
# 624              0              16 -0.7833   6889000000        0
# 634              0              16 -0.8639   8397000000        0
# 640              0              16  0.6465   8877000000        1
# 659              0              16  5.9779  19999000000        1
# 666              4              12  3.1209  10666000000        1
# 678              4              12  1.4432  11328000000        1
# 682              4              12  3.1852  29644000000        1
# 699              4              12  4.5381   8668000000        1
# 701              4              12  0.4314  11911000000        1
# 715              4              12  0.7039   5702000000        1
#
# [72 rows x 26 columns]

# %%
dat1=dat[dat.apply(lambda x: x.treatment==1 and x.rounds<6, axis=1)]
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
dat1.rt.hist(bins=50,  ax=ax, density=True, histtype="stepfilled")
plt.legend(["0 or 4: +; 2: -"])
plt.savefig('elias_rt_logscale_round1.png')

# %%
dat1=dat[dat.apply(lambda x: x.rounds==10, axis=1)]
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
dat1.rt.hist(bins=50,  ax=ax, density=True, histtype="stepfilled")
plt.legend(["0 or 4: +; 2: -"])
plt.savefig('elias_rt_logscale_round10.png')
