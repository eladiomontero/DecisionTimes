# %% [markdown]
# The drift difussion model (DDM) is a type of sequential sampling model (SSM) which, until now, has been uniquely applied in impulsive / non-deliberated two-choice decisions. These SSM models, and thus the DDM, assume that decisions are made by accumulating information until a threshold is reached. In order to model this accumulation of knowledge, DDM uses a random walk in two dimensions, starting at point z and finishing when it reaches a decision threshold (a or 0).
#
# The starting point z can be understood as an initial bias, which can be due to previous experiences or intuitive notions. On the other hand, the boundaries represent the minimum accumulated knowledge needed to make a decision, so harder decisions will have wider boundaries than simple choices.
#
# The speed by which the information is accumulated is defined as $v$ (drift rate) and it is a constant value throughout the experiment. In past papers, the drift rate $v$ has been defined positive when the accumulation of information led to the right decision (and negative in the opposite case) but, as decisions in cooperation-defection experiments are not right or wrong, $v$ will be defined as positive when the accumulation of knowledge leads to a cooperative choice (and negative on the contrary).
#
# Apart from the drift rate, there is a source of stochastic noise in the decision process. Using the same parameters v and z, this noise will lead to different final decisions and different final times. Thevariability in decision times will produce the characteristic distribution of RT (reaction time) and the two possible final decisions will bring errors and the corresponding error RT distribution.
#
# One last parameter $t_0$?
#
# The equation which represents the probability distribution:
# $$P(t| v,a,z)=\frac{\pi}{a^2}\exp{(-vza-\frac{v^2 t}{2})} × \sum_{k=1}^\infty k \exp{(-\frac{k^2\pi ^2 t}{2a^2})}\sin{(k\pi z)}$$

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5112760/
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4928591/
# http://star.psy.ohio-state.edu/wp/?page_id=169

# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
# %matplotlib inline
import hddm
print(hddm.__version__)
from math import pi as pi
from math import exp as exp
from math import sin as sin
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\IPython\parallel.py:13: ShimWarning: The `IPython.parallel` package has been deprecated since IPython 4.0. You should import from ipyparallel instead.
#   "You should import from ipyparallel instead.", ShimWarning)
# 0.6.0

# %% [markdown]
# # File parsing

# %%
def parse_files(files_to_parse,outfile):
    o=open(outfile+".dat","w")
    for index,i in enumerate(files_to_parse):
        if index==0:
            for line in open("Esther/history_"+i+".dat"):
                o.write(line.replace(" ",",").replace("usuario",i+"_usuario")) 
        else:
            f=open("Esther/history_"+i+".dat")
            f.readline()
            for line in f:
                o.write(line.replace(" ",",").replace("usuario",i+"_usuario") ) 
    o.close()
    return

# %% [markdown]
# # Data preprocessing

# %%
def preprocessing(data):#only user (not autom)
    data=data[data["who_played"]=="user"]

    #delete problematic columns
    del data["who_played"], data["opponent"], data["payoff"], data["time_php"], data["action_opponent"]

    #rename rt, userid and response columns
    data.rename(columns={'time_js':'rt', "action_player":"response", "player":"userid"}, inplace=True) 

    #make rt integers and seconds
    data['rt'] = data.rt.astype(int)/1000

    #coop is 1, defect is 0
    data.loc[data['response'] == "C", "response"] = 1.0
    data.loc[data['response'] == "D", "response"] = 0.0

    #standard deviation for bin width selection
    print("STD of data is ", data["rt"].std())

    #rt which are defective become neg
    data = hddm.utils.flip_errors(data)

    #see how many decisions we hav
    print("N of decisions are ",data.shape[0])

    #see how the df looks like
    data.head()
    return data

# %% [markdown]
# # Times distribution

# %%
def plot_norm_distrib(output_filename,data,logscale):
    fig = plt.figure(figsize=(14,10), )
    if logscale:
        ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (LOG SCALE)'+output_filename)
        data.rt.hist(log=True,bins=300,  ax=ax, density=True, histtype="stepfilled")
        plt.legend(["coop: +; defect: -"])
        plt.xlim(-30,30)
        plt.savefig(output_filename+'_logscale.png')
    else:
        ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions '+output_filename)
        data.rt.hist(bins=300,  ax=ax, density=True, histtype="stepfilled")
        plt.legend(["coop: +; defect: -"])
        plt.xlim(-30,30)
        plt.savefig(output_filename+'.png')
    return

# %% [markdown]
# # Get graph from parameters

# %%
def DDM(t,a,v,t0,z,kmax=1000):
    if t < t0:
        return 0
    else:
        x = t-t0
        c1 = pi/a**2 * exp(-v*z*a - v**2*x/2)
        c2 = 0
        for k in range(1,kmax):
            c2 += k*exp(-k**2*pi**2*x/(2*a**2))*sin(k*pi*z)
        return c1*c2

# %% [markdown]
# # Weak PD with fixed partners

# %%
files_to_parse=["s3m7"]#,"s4m8","s5m20","s6m22","s7m22","s8n3","s9n3","s10n5","s11n9","s13n12","s12n11"
parse_files(files_to_parse,"weakPD_fixpart")
data = hddm.load_csv('weakPD_fixpart.dat')
data.head()
# Out:
#    round          player action_player            opponent action_opponent  \
# 0      1   s3m7_usuario9             D  ['s3m7_usuario18']               C
# 1      1  s3m7_usuario18             C   ['s3m7_usuario9']               D
# 2      1   s3m7_usuario7             C  ['s3m7_usuario10']               C
# 3      1  s3m7_usuario10             C   ['s3m7_usuario7']               C
# 4      1  s3m7_usuario13             C   ['s3m7_usuario5']               C
#
#    payoff     time_php  time_js who_played
# 0       4  4480.199814     4452       user
# 1       0  9472.300053     9443       user
# 2       3  2238.199949     2213       user
# 3       3  8133.699894     8101       user
# 4       3  5098.500013     5043       user

# %%
data=preprocessing(data)
data.head()
# Out:
# STD of data is  2.19408775652
# N of decisions are  1800
#    round          userid  response     rt
# 0      1   s3m7_usuario9         0 -4.452
# 1      1  s3m7_usuario18         1  9.443
# 2      1   s3m7_usuario7         1  2.213
# 3      1  s3m7_usuario10         1  8.101
# 4      1  s3m7_usuario13         1  5.043

# %%
plot_norm_distrib("weakPD",data,False)

# %%
plot_norm_distrib("weakPD",data,True)

# %% [markdown]
# # Fixed partners

# %%
files_to_parse2=['s4m8','s8n3','s9n3','s10n5']#'s1m5','s2m5',
parse_files(files_to_parse2, "PD_fixedpart")
data2=hddm.load_csv("PD_fixedpart.dat")
data2.head()
# Out:
#    round          player action_player            opponent action_opponent  \
# 0      1   s4m8_usuario2             D   ['s4m8_usuario7']               C
# 1      1   s4m8_usuario7             C   ['s4m8_usuario2']               D
# 2      1  s4m8_usuario14             C  ['s4m8_usuario13']               C
# 3      1  s4m8_usuario13             C  ['s4m8_usuario14']               C
# 4      1   s4m8_usuario9             D  ['s4m8_usuario10']               C
#
#    payoff      time_php  time_js who_played
# 0       4   4616.299868     4600       user
# 1       0   4081.799984     4055       user
# 2       3   5450.299978     5394       user
# 3       3   7837.399960     7806       user
# 4       4  15086.500168    15067       user

# %%
data2=preprocessing(data2)
data2.head()
# Out:
# STD of data is  2.89876235343
# N of decisions are  5800
#    round          userid  response      rt
# 0      1   s4m8_usuario2         0  -4.600
# 1      1   s4m8_usuario7         1   4.055
# 2      1  s4m8_usuario14         1   5.394
# 3      1  s4m8_usuario13         1   7.806
# 4      1   s4m8_usuario9         0 -15.067

# %%
plot_norm_distrib("PD_fixedpartners",data2,False)

# %%
plot_norm_distrib("PD_fixedpartners",data2,True)

# %% [markdown]
# # Different partners every round

# %%
files_to_parse3=['s5m20','s6m22','s7m22','s11n9','s12n11','s13n12']
parse_files(files_to_parse3, "PD_diffpart")
data3=hddm.load_csv("PD_diffpart.dat")
data3.head()
# Out:
#    round          player action_player             opponent action_opponent  \
# 0      1  s5m20_usuario1             D  ['s5m20_usuario12']               D
# 1      1  s5m20_usuario2             C  ['s5m20_usuario10']               D
# 2      1  s5m20_usuario3             D   ['s5m20_usuario5']               D
# 3      1  s5m20_usuario4             C  ['s5m20_usuario13']               C
# 4      1  s5m20_usuario5             D   ['s5m20_usuario3']               D
#
#    payoff      time_php  time_js who_played
# 0       1   6705.299854     6678       user
# 1       0   4630.299807     4601       user
# 2       1  12807.000160    12777       user
# 3       3   2428.100109     2399       user
# 4       1  17117.100000    17088       user

# %%
data3=preprocessing(data3)
data3.head()
# Out:
# STD of data is  3.07694173519
# N of decisions are  9600
#    round          userid  response      rt
# 0      1  s5m20_usuario1         0  -6.678
# 1      1  s5m20_usuario2         1   4.601
# 2      1  s5m20_usuario3         0 -12.777
# 3      1  s5m20_usuario4         1   2.399
# 4      1  s5m20_usuario5         0 -17.088

# %%
plot_norm_distrib("PD_changingpartners",data3,False)

# %%
plot_norm_distrib("PD_fixedpartners",data3,True)

# %% [markdown]
# # Bin size
# For any histogram, the bin size follows eq (https://www.fmrib.ox.ac.uk/datasets/techrep/tr00mj2/tr00mj2/node24.html):
# $$W=3.49 \sigma N^{-1/3}$$
#
# here $\sigma$ equals 2,94 and N equals 17200.
# $$W=0.39749341805822797$$
# so the number of bins has to be
# $$60/W=150$$
# as the data is split in 2 sides (positive for cooperation times and negative for defection times) we use 300 bins.

# %% [markdown]
# # Quality of data
# In order to assess the quality of the data, a statistical test is carried out over the following parameters: drift rate v, initial bias z, non-decision time t and decision boundary a. A first statistical analysis can be done with the autocorrelation, the trace and the histogram for each parameter.
#
# Autocorrelation coefficient at lag k is obtained from the following eq.
# $$r_k=\frac{\sum_{i=1}^{N-k} (x_i-\bar{x})(x_{i+k}-\bar{x})}{\sum_{i=1}^N(x_i-\bar{x})^2}$$
# These autocorrelation graphs show
#
# On the other hand, the trace shows how stationary the obtained parameters are. As some data values are discarded on the first rounds, we need to make sure that the parameter has become steady.

# %% [markdown]
# # Sample and burn number?

# %%
def fit_data(data):
    model = hddm.HDDM(data, include='z')
    model.sample(2000, burn=20)
    stat=model.gen_stats() 
    print(stat)
    model.plot_posteriors()
#no drifts or large jumps in the trace (non stationary). The autocorrelation is also very low.

# %%
model = hddm.HDDM(data, include='z')
model.sample(2000, burn=100)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
#no drifts or large jumps in the trace (non stationary). The autocorrelation is also very low.

# %%
model = hddm.HDDM(data, include='z')
model.sample(5000, burn=100)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
#no drifts or large jumps in the trace (non stationary). The autocorrelation is also very low.

# %%
model = hddm.HDDM(data, include='z')
model.sample(200, burn=10)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
#no drifts or large jumps in the trace (non stationary). The autocorrelation is also very low.

# %%
model = hddm.HDDM(data, include='z')
model.sample(2000, burn=10)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
#no drifts or large jumps in the trace (non stationary). The autocorrelation is also very low.

# %%
model = hddm.HDDM(data, include='z')
model.sample(2000, burn=100)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()

# %% [markdown]
# # Model fitting data

# %%
def get_model(data,sampleN,burnN):
    model = hddm.HDDM(data, include='z')
    model.sample(sampleN, burn=burnN)
    stat=model.gen_stats() 
    #print(stat["mean"])
    model.plot_posteriors()
    model.plot_posterior_predictive()
    plt.title('Posterior predictive')
    plt.xlabel('RT')
    plt.ylabel('Probability density')
    return stat


def get_manual_fitting(output_filename,data,stat,nbins,ylimit,xlimit):
    val_neg=[DDM(i/100,stat["mean"]["a"],stat["mean"]["v"],stat["mean"]["t"],stat["mean"]["z"]) for i in range(100*xlimit)]
    val_pos=[DDM(i/100,stat["mean"]["a"],-1*stat["mean"]["v"],stat["mean"]["t"],1-stat["mean"]["z"]) for i in range(100*xlimit)]
    xval_neg=[-i/100 for i in range(100*xlimit)]
    xval_pos=[i/100 for i in range(100*xlimit)]

    fig = plt.figure(figsize=(14,10), )
    ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions ')
    #dataOut.rt.hist(bins=300,  ax=ax, density=True, histtype="stepfilled")
    plt.plot(xval_pos,val_pos)
    plt.plot(xval_neg,val_neg)
    plt.xlim(-xlimit*1.5,xlimit*1.5)
    plt.yscale("log")

    counts,bin_edges = np.histogram(data["rt"],nbins,normed=True)
    bin_centres = (bin_edges[:-1] + bin_edges[1:])/2.
    plt.errorbar(bin_centres, counts, yerr=0, fmt='o')
    plt.ylim(ylimit)
    plt.legend(stat["mean"])
    plt.savefig(output_filename+".png")
    plt.show()
    return

# %%
stat=get_model(data,1000,200)
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 1000 of 1000 complete in 29.6 secPlotting a
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# Plotting v
# Plotting t
# Plotting z
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
get_manual_fitting("weakPD_fitting",data,stat,60,5e-4,10)

# %%
stat2=get_model(data2,1000,200)
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 1000 of 1000 complete in 104.0 secPlotting a
# Plotting v
# Plotting t
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# Plotting z
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
get_manual_fitting("PDfixedpartners_fitting",data2,stat2,70,2e-4,15)

# %%
stat3=get_model(data3,1000,200)
# Out:
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\pymc\Node.py:403: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   self.__name__ = input['__name__']
#  [-----------------100%-----------------] 1000 of 1000 complete in 180.4 secPlotting a
# Plotting v
# Plotting t
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\numpy\core\fromnumeric.py:224: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   return reshape(newshape, order=order)
# Plotting z
# C:\Users\Esther Rodrigo\AppData\Local\conda\conda\envs\hddm-related\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
get_manual_fitting("PDchangepartners_fitting",data3,stat3,50,1e-4,15)

# %% [markdown]
# # cut at t=40 sec, all data

# %%
#high correlation
#trace ok because it fluctuates around mean final value
model = hddm.HDDM(data, include='z')
model.sample(200, burn=100)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
model.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig('jelena_rt_aprox.pdf')

# %%
val=[DDM(i,stat["mean"]["a"],stat["mean"]["v"],stat["mean"]["t"],stat["mean"]["z"]) for i in range(40)]

fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions ')
data.rt.hist(bins=300,  ax=ax, density=True, histtype="stepfilled")
plt.plot(val)

# %% [markdown]
# # cut at t=35 sec, all data

# %%
model = hddm.HDDM(data, include='z')
model.sample(200, burn=100)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
model.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig('jelena_rt_aprox.pdf')

val=[DDM(i,stat["mean"]["a"],stat["mean"]["v"],stat["mean"]["t"],stat["mean"]["z"]) for i in range(40)]

fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions ')
data.rt.hist(bins=300,  ax=ax, density=True, histtype="stepfilled")
plt.plot(val)

# %% [markdown]
# ## with outliers and cutting at 35

# %%
model = hddm.HDDM(data, p_outlier=.05, include='z')
model.sample(200, burn=100)
stat=model.gen_stats() 
print(stat)
model.plot_posteriors()
model.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig('jelena_rt_aprox.pdf')

# %%
val=[DDM(i,stat["mean"]["a"],stat["mean"]["v"],stat["mean"]["t"],stat["mean"]["z"]) for i in range(40)]

fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions ')
data.rt.hist(bins=176,  ax=ax, density=True, histtype="stepfilled")
plt.plot(val)

# %%
val=[DDM(i,stat["mean"]["a"],stat["mean"]["v"],stat["mean"]["t"],stat["mean"]["z"]) for i in range(-40,40)]

fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions ')
data.rt.hist(bins=300,  ax=ax, density=True, histtype="stepfilled")
plt.plot(val)

# %%
#get statistics from a t z and v
stats = model.gen_stats()
stats[stats.index.isin(['a', "t", 'v',"z"])]

# %%
#basic model by players
m2 = hddm.HDDM(data2, p_outlier=.05)
# find a good starting point which helps with the convergence.
m2.find_starting_values()
m2.sample(2000, burn=20)
#by player
m2.plot_posterior_predictive(figsize=(24, 60))
#m2.gen_starts()

# %%
stats2 = m2.gen_stats()
print(stats2["z"])

# %%
#distribution depending on strategy
m_stim = hddm.HDDM(data, depends_on={'v': 'strategy'})
m_stim.find_starting_values()
m_stim.sample(10000, burn=1000)

v_WW, v_LL, v_WL,v_LW = m_stim.nodes_db.node[['v(00)', 'v(01)', 'v(10)','v(11)']]
hddm.analyze.plot_posterior_nodes([v_WW, v_LL, v_WL, v_LW])
plt.xlabel('drift-rate')
plt.ylabel('Posterior probability')
plt.title('Posterior of drift-rate group means')
plt.savefig('hddm_demo_fig_06.pdf')

# %%
#comparing distributions: dealing with outliers 
#comaprison with outlayers to see which model fits better
m_no_outlier = hddm.HDDM(data, include="z")
m_no_outlier.sample(2000, burn=20)
m_no_outlier.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
#plt.savefig('hddm_demo_fig_10.pdf')

m_outlier = hddm.HDDM(data, include="z",p_outlier=.05)
m_outlier.sample(2000, burn=20)
m_outlier.plot_posterior_predictive()
plt.title('Posterior predictive excluding outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
stats3=m_outlier.gen_stats()
print(stats3)

# %%
#by player

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, xlabel='RT', ylabel='count', title='RT distributions')
for i, subj_data in data.groupby("player"):
    subj_data.rt.hist(log=True,bins=200,  ax=ax,histtype="step")
print(len(data.groupby("player")))
#plt.savefig('hddm_demo_fig_00.pdf')

# %%
#if we want analisis by player change player by subj_idx

m_outlier = hddm.HDDM(data, p_outlier=.05)
m_outlier.sample(2000, burn=20)
m_outlier.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig('jelena_rt_aprox.pdf')

# %%
#by strategy
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm', title='RT distributions')
for i, subj_data in data.groupby("strategy"):
    subj_data.rt.hist(bins=200,  ax=ax, density=True)
fig.legend(["00","01","10","11"])
#plt.savefig('hddm_demo_fig_00.pdf')
#if player cooperates, oponent choice does not matter for decision time. ohter player choice only matters when we defect

# %%
model = hddm.HDDM(data)

# Create model and start MCMC sampling
model.sample(200, burn=20)

# Print fitted parameters and other model statistics
model.print_stats()

# Plot posterior distributions and theoretical RT distributions
model.plot_posteriors()
model.plot_posterior_predictive()

# %%
#posterior prediction?

# %% [markdown]
# ## Dec Times Elias

# %%
dat = hddm.load_csv('crd_dataset_time_ns.csv')
del dat["time_elapsed_action"], dat["time_elapsed_pred"]
dat.rename(columns={"etimeactionnr":"rt"},inplace=True)
#0 and 4 extreme become 1, 2 becomes 0
dat["response"]=[1 if( dat["actions"][i]==0 or dat["actions"][i]==4) else 0 for i in range(len(dat))]
#rt which are defect become neg
dat = hddm.utils.flip_errors(dat)
dat["rt"]=dat["rt"]/10e9
two=dat[dat["actions"]==2]
zero=dat[dat["actions"]==0]
four=dat[dat["actions"]==4]
dat.head()

# %%
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions')
data.rt.hist(bins="auto",  ax=ax, density=True, histtype="stepfilled")
plt.legend(["coop: +; defect: -"])
plt.savefig('elias_rt.png')

# %%
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
dat.rt.hist(log=True,bins=200,  ax=ax, density=True, histtype="stepfilled")
plt.legend(["0 or 4: +; 2: -"])
plt.savefig('elias_rt_logscale.png')

# %%
m_outlier = hddm.HDDM(dat, include="z", p_outlier=.05)
m_outlier.sample(2000, burn=20)
m_outlier.plot_posterior_predictive()
plt.title('Posterior predictive considering outliers')
plt.xlabel('RT')
plt.ylabel('Probability density')
plt.savefig("elias_rt_aprox.pdf")
statse=m_outlier.gen_stats()
print(statse)

# %%
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm', title='RT distributions')
for i, subj_data in dat.groupby("actions"):
    subj_data.rt.hist(bins=200,  ax=ax, density=True)
fig.legend(["0","2","4"])

# %%
dat1=dat[dat["rounds"]==1]
dat2=dat[(dat["rounds"]==10)  & (dat["treatment"]==1)]
print(dat2)

# %%
dat1=dat[dat.apply(lambda x: x.treatment==1 and x.rounds<6, axis=1)]
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
dat1.rt.hist(bins=50,  ax=ax, density=True, histtype="stepfilled")
plt.legend(["0 or 4: +; 2: -"])
plt.savefig('elias_rt_logscale_round1.png')

# %%
dat1=dat[dat.apply(lambda x: x.rounds==10, axis=1)]
fig = plt.figure(figsize=(14,10), )
ax = fig.add_subplot(111, xlabel='RT (s)', ylabel='p(t) norm. count', title='RT distributions (log scale)')
dat1.rt.hist(bins=50,  ax=ax, density=True, histtype="stepfilled")
plt.legend(["0 or 4: +; 2: -"])
plt.savefig('elias_rt_logscale_round10.png')

# %%
dataOut=data.copy()
data35=data.copy()
#select range to delete outsiders
data35=data35[(data35["rt"]<35) & (data35["rt"]>-35)]

data40=data.copy()
#select range to delete outsiders
data40=data40[(data40["rt"]<40) & (data40["rt"]>-40)]

dataO30=dataOut.copy()
dataO30=dataO10[(dataO30["rt"]<30) & (dataO30["rt"]>-30)]
